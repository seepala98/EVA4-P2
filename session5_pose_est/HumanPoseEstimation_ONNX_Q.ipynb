# %% [markdown]
# # Monocular Single Human Pose Estimation

# %%
! git clone https://github.com/microsoft/human-pose-estimation.pytorch && cd human-pose-estimation.pytorch && git checkout 18f1d0fa5b5db7fe08de640610f3fdbdbed8fb2f
# Out:
# Cloning into 'human-pose-estimation.pytorch'...
# remote: Enumerating objects: 188, done.
# remote: Total 188 (delta 0), reused 0 (delta 0), pack-reused 188
# Receiving objects: 100% (188/188), 68.78 KiB | 5.73 MiB/s, done.
# Resolving deltas: 100% (86/86), done.
# Note: checking out '18f1d0fa5b5db7fe08de640610f3fdbdbed8fb2f'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at 18f1d0f Update README.md

# %%
! pip install onnx onnxruntime
# Out:
# Collecting onnx
#   Downloading https://files.pythonhosted.org/packages/36/ee/bc7bc88fc8449266add978627e90c363069211584b937fd867b0ccc59f09/onnx-1.7.0-cp36-cp36m-manylinux1_x86_64.whl (7.4MB)
#      |████████████████████████████████| 7.4MB 3.9MB/s
# Collecting onnxruntime
#   Downloading https://files.pythonhosted.org/packages/14/a6/30c6c17524d6930df677412eda0b3c2acd9062697fc0e86842f2dd058835/onnxruntime-1.4.0-cp36-cp36m-manylinux2010_x86_64.whl (4.4MB)
#      |████████████████████████████████| 4.4MB 29.1MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from onnx) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from onnx) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.6/dist-packages (from onnx) (3.7.4.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from onnx) (3.12.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->onnx) (49.6.0)
# Installing collected packages: onnx, onnxruntime
# Successfully installed onnx-1.7.0 onnxruntime-1.4.0

# %%
import sys
if "/content/human-pose-estimation.pytorch/lib/" not in sys.path:
    sys.path.insert(0, "/content/human-pose-estimation.pytorch/lib/")

# %%
import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.optim
import torchvision.transforms as T

import cv2

import re
import os
import copy
import numpy as np

from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import models
from core.config import config
from core.config import update_config
from core.config import update_dir
from core.config import get_model_name

# %% [markdown]
# We are going to use MPII - ResNet50 Model trained on `256x256` sized images
# model_file: https://drive.google.com/file/d/1V2AaVpDSn-eS7jrFScHLJ-wvTFuQ0-Dc/view?usp=sharing

# %%
! gdown https://drive.google.com/uc?id=1V2AaVpDSn-eS7jrFScHLJ-wvTFuQ0-Dc
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1V2AaVpDSn-eS7jrFScHLJ-wvTFuQ0-Dc
# To: /content/pose_resnet_50_256x256.pth.tar
# 136MB [00:01, 102MB/s]

# %% [markdown]
# The corresponding config file is taken from experiments folder

# %%
CONFIG_FILE = '/content/human-pose-estimation.pytorch/experiments/mpii/resnet50/256x256_d256x3_adam_lr1e-3.yaml'
MODEL_PATH = '/content/pose_resnet_50_256x256.pth.tar'

# %%
update_config(CONFIG_FILE)
config.GPUS = '' # we are running on CPU

# %% [markdown]
# Load the model

# %%
model = eval('models.'+config.MODEL.NAME+'.get_pose_net')(config, is_train=False)
model.load_state_dict(torch.load(MODEL_PATH, map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Pose Lady

# %%
! wget https://foreignpolicy.com/wp-content/uploads/2015/12/gettyimages-499714478.jpg -O pose.jpg
# Out:
# --2020-09-04 13:56:14--  https://foreignpolicy.com/wp-content/uploads/2015/12/gettyimages-499714478.jpg
# Resolving foreignpolicy.com (foreignpolicy.com)... 192.0.66.136
# Connecting to foreignpolicy.com (foreignpolicy.com)|192.0.66.136|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2296635 (2.2M) [image/jpeg]
# Saving to: ‘pose.jpg’
#
# pose.jpg            100%[===================>]   2.19M  12.0MB/s    in 0.2s
#
# 2020-09-04 13:56:14 (12.0 MB/s) - ‘pose.jpg’ saved [2296635/2296635]

# %%
! wget https://www.kindpng.com/picc/m/184-1844112_putin-standing-png-transparent-png.png -O pose.jpg
# Out:
# --2020-09-04 13:58:08--  https://www.kindpng.com/picc/m/184-1844112_putin-standing-png-transparent-png.png
# Resolving www.kindpng.com (www.kindpng.com)... 70.36.99.229
# Connecting to www.kindpng.com (www.kindpng.com)|70.36.99.229|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 202914 (198K) [image/png]
# Saving to: ‘pose.jpg’
#
# pose.jpg            100%[===================>] 198.16K  --.-KB/s    in 0.09s
#
# 2020-09-04 13:58:08 (2.22 MB/s) - ‘pose.jpg’ saved [202914/202914]

# %% [markdown]
# Pose Man

# %%
IMAGE_FILE = 'pose.jpg'

# %%
image = Image.open(IMAGE_FILE)
image = image.convert('RGB')
image
# Out:
# <PIL.Image.Image image mode=RGB size=860x983 at 0x7F608250C080>

# %%
transform = T.Compose([
                       T.Resize((256, 256)),
                       T.ToTensor(),
                       T.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
                       ])

# %% [markdown]
# Transform the image for the model

# %%
tr_img = transform(image)

# %% [markdown]
# Pass the Image through the model

# %%
output = model(tr_img.unsqueeze(0))
output = output.squeeze(0)

# %%
_, OUT_HEIGHT, OUT_WIDTH = output.shape
output.shape
# Out:
# torch.Size([16, 64, 64])

# %%
get_detached = lambda x: copy.deepcopy(x.cpu().detach().numpy())

# %% [markdown]
# `joint_id` - name
# taken from: http://human-pose.mpi-inf.mpg.de/#download

# %%
JOINTS = ['0 - r ankle', '1 - r knee', '2 - r hip', '3 - l hip', '4 - l knee', '5 - l ankle', '6 - pelvis', '7 - thorax', '8 - upper neck', '9 - head top', '10 - r wrist', '11 - r elbow', '12 - r shoulder', '13 - l shoulder', '14 - l elbow', '15 - l wrist']
JOINTS = [re.sub(r'[0-9]+|-', '', joint).strip().replace(' ', '-') for joint in JOINTS]

# %%
POSE_PAIRS = [
# UPPER BODY
              [9, 8],
              [8, 7],
              [7, 6],

# LOWER BODY
              [6, 2],
              [2, 1],
              [1, 0],

              [6, 3],
              [3, 4],
              [4, 5],

# ARMS
              [7, 12],
              [12, 11],
              [11, 10],

              [7, 13],
              [13, 14],
              [14, 15]
]

# %%
from operator import itemgetter
get_keypoints = lambda pose_layers: map(itemgetter(1, 3), [cv2.minMaxLoc(pose_layer) for pose_layer in pose_layers])

# %% [markdown]
# Here are all the detections

# %%
plt.figure(figsize=(15, 15))
for idx, pose_layer in enumerate(get_detached(output)):
    # print(pose_layer.shape)
    plt.subplot(4, 4, idx + 1)
    plt.title(f'{idx} - {JOINTS[idx]}')
    plt.imshow(image.resize((OUT_WIDTH, OUT_HEIGHT)), cmap='gray', interpolation='bicubic')
    plt.imshow(pose_layer, alpha=0.5, cmap='jet', interpolation='bicubic')
    plt.axis('off')
plt.show()

# %% [markdown]
# Here are the detections summarised in a single image

# %%
plt.figure(figsize=(8, 8))
plt.imshow(image.resize((OUT_WIDTH, OUT_HEIGHT)), cmap='gray', interpolation='bicubic')
pose_layers = get_detached(output)
pose_layers = np.clip(pose_layers, 0.7, 1.0)
layer_sum = np.sum(pose_layers, axis=0)
plt.imshow(layer_sum, alpha=0.5, cmap='jet', interpolation='bicubic')
plt.axis('off')
plt.show()

# %% [markdown]
# Now we will connect these detected regions

# %%
THRESHOLD = 0.8
OUT_SHAPE = (OUT_HEIGHT, OUT_WIDTH)
image_p = cv2.imread(IMAGE_FILE)
pose_layers = get_detached(x=output)
key_points = list(get_keypoints(pose_layers=pose_layers))
is_joint_plotted = [False for i in range(len(JOINTS))]
for pose_pair in POSE_PAIRS:
    from_j, to_j = pose_pair

    from_thr, (from_x_j, from_y_j) = key_points[from_j]
    to_thr, (to_x_j, to_y_j) = key_points[to_j]

    IMG_HEIGHT, IMG_WIDTH, _ = image_p.shape

    from_x_j, to_x_j = from_x_j * IMG_WIDTH / OUT_SHAPE[0], to_x_j * IMG_WIDTH / OUT_SHAPE[0]
    from_y_j, to_y_j = from_y_j * IMG_HEIGHT / OUT_SHAPE[1], to_y_j * IMG_HEIGHT / OUT_SHAPE[1]

    from_x_j, to_x_j = int(from_x_j), int(to_x_j)
    from_y_j, to_y_j = int(from_y_j), int(to_y_j)

    if from_thr > THRESHOLD and not is_joint_plotted[from_j]:
        # this is a joint
        cv2.ellipse(image_p, (from_x_j, from_y_j), (4, 4), 0, 0, 360, (255, 255, 255), cv2.FILLED)
        is_joint_plotted[from_j] = True

    if to_thr > THRESHOLD and not is_joint_plotted[to_j]:
        # this is a joint
        cv2.ellipse(image_p, (to_x_j, to_y_j), (4, 4), 0, 0, 360, (255, 255, 255), cv2.FILLED)
        is_joint_plotted[to_j] = True

    if from_thr > THRESHOLD and to_thr > THRESHOLD:
        # this is a joint connection, plot a line
        cv2.line(image_p, (from_x_j, from_y_j), (to_x_j, to_y_j), (255, 74, 0), 3)

# %% [markdown]
# ### Our final image with the estimated pose !

# %%
Image.fromarray(cv2.cvtColor(image_p, cv2.COLOR_RGB2BGR))
# Out:
# <PIL.Image.Image image mode=RGB size=860x983 at 0x7F60825F10F0>

# %% [markdown]
# ## Convert to ONNX and quantize the model

# %%
def print_size_of_model(model):
    torch.save(model.state_dict(), "temp.p")
    print('Size (MB):', os.path.getsize("temp.p")/1e6)
    os.remove('temp.p')

def print_size_of_onnx_model(model):
    onnx.save(model, 'temp.onnx')
    print('Size (MB):', os.path.getsize("temp.onnx")/1e6)
    os.remove('temp.onnx')

# %% [markdown]
# PyTorch Model Size

# %%
print_size_of_model(model)
# Out:
# Size (MB): 136.326147

# %%
new_model = copy.deepcopy(model)

# %% [markdown]
# Now we will Convert this model to ONNX

# %%
import io
import numpy as np
import torch.onnx

# %%
# Input to the model
torch_model = new_model
batch_size = 1
x = torch.randn(batch_size, 3, 256, 256, requires_grad=True)
torch_out = torch_model(x)

# Export the model
torch.onnx.export(torch_model,               # model being run
                  x,                         # model input (or a tuple for multiple inputs)
                  "simple_pose_estimation.onnx",   # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=10,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['input'],   # the model's input names
                  output_names = ['output'], # the model's output names
                  dynamic_axes={'input' : {0 : 'batch_size'},    # variable lenght axes
                                'output' : {0 : 'batch_size'}})

# %%
import onnx

onnx_model = onnx.load("simple_pose_estimation.onnx")
onnx.checker.check_model(onnx_model)

# %% [markdown]
# Let's just check the size of the saved ONNX Model

# %%
print_size_of_onnx_model(onnx_model)
# Out:
# Size (MB): 136.247923

# %% [markdown]
# And also lets quicky test if the model works

# %%
import onnxruntime

ort_session = onnxruntime.InferenceSession("simple_pose_estimation.onnx")

def to_numpy(tensor):
    return tensor.detach().cpu().numpy() if tensor.requires_grad else tensor.cpu().numpy()

# compute ONNX Runtime output prediction
ort_inputs = {ort_session.get_inputs()[0].name: to_numpy(tr_img.unsqueeze(0))}
ort_outs = ort_session.run(None, ort_inputs)

# %%
ort_outs = ort_outs[0][0]

# %%
len(ort_outs)
# Out:
# 16

# %% [markdown]
# ### ONNX Model Quantization

# %%
from onnxruntime.quantization import quantize
from onnxruntime.quantization import QuantizationMode

# %%
quantized_model = quantize(onnx_model, quantization_mode=QuantizationMode.IntegerOps, static=False)

# %%
onnx.save(quantized_model, 'simple_pose_estimation.quantized.onnx')

# %% [markdown]
# The Quantized Model is Half the Size ! (as expected but still yayyy !)

# %%
print_size_of_onnx_model(quantized_model)
# Out:
# Size (MB): 65.933789

# %% [markdown]
# Let's now test if the quantized model works

# %%
import onnxruntime

ort_session = onnxruntime.InferenceSession("simple_pose_estimation.quantized.onnx")

def to_numpy(tensor):
    return tensor.detach().cpu().numpy() if tensor.requires_grad else tensor.cpu().numpy()

# compute ONNX Runtime output prediction
ort_inputs = {ort_session.get_inputs()[0].name: to_numpy(tr_img.unsqueeze(0))}
ort_outs = ort_session.run(None, ort_inputs)

# %%
np.array(ort_outs).shape
# Out:
# (1, 1, 16, 64, 64)

# %%
ort_outs = np.array(ort_outs[0][0])

# %%
THRESHOLD = 0.8
OUT_SHAPE = (OUT_HEIGHT, OUT_WIDTH)
image_p = cv2.imread(IMAGE_FILE)
pose_layers = ort_outs
key_points = list(get_keypoints(pose_layers=pose_layers))
is_joint_plotted = [False for i in range(len(JOINTS))]
for pose_pair in POSE_PAIRS:
    from_j, to_j = pose_pair

    from_thr, (from_x_j, from_y_j) = key_points[from_j]
    to_thr, (to_x_j, to_y_j) = key_points[to_j]

    IMG_HEIGHT, IMG_WIDTH, _ = image_p.shape

    from_x_j, to_x_j = from_x_j * IMG_WIDTH / OUT_SHAPE[0], to_x_j * IMG_WIDTH / OUT_SHAPE[0]
    from_y_j, to_y_j = from_y_j * IMG_HEIGHT / OUT_SHAPE[1], to_y_j * IMG_HEIGHT / OUT_SHAPE[1]

    from_x_j, to_x_j = int(from_x_j), int(to_x_j)
    from_y_j, to_y_j = int(from_y_j), int(to_y_j)

    if from_thr > THRESHOLD and not is_joint_plotted[from_j]:
        # this is a joint
        cv2.ellipse(image_p, (from_x_j, from_y_j), (4, 4), 0, 0, 360, (255, 255, 255), cv2.FILLED)
        is_joint_plotted[from_j] = True

    if to_thr > THRESHOLD and not is_joint_plotted[to_j]:
        # this is a joint
        cv2.ellipse(image_p, (to_x_j, to_y_j), (4, 4), 0, 0, 360, (255, 255, 255), cv2.FILLED)
        is_joint_plotted[to_j] = True

    if from_thr > THRESHOLD and to_thr > THRESHOLD:
        # this is a joint connection, plot a line
        cv2.line(image_p, (from_x_j, from_y_j), (to_x_j, to_y_j), (255, 74, 0), 3)

# %% [markdown]
# Pretty similar results !? eh ?

# %%
Image.fromarray(cv2.cvtColor(image_p, cv2.COLOR_RGB2BGR))
# Out:
# <PIL.Image.Image image mode=RGB size=860x983 at 0x7F60827305F8>

# %%
# !zip -r /content/pose_zip.zip /content/*
# Out:
#   adding: content/human-pose-estimation.pytorch/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/requirements.txt (deflated 11%)
#   adding: content/human-pose-estimation.pytorch/lib/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/lib/Makefile (deflated 23%)
#   adding: content/human-pose-estimation.pytorch/lib/nms/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/lib/nms/cpu_nms.pyx (deflated 67%)
#   adding: content/human-pose-estimation.pytorch/lib/nms/gpu_nms.hpp (deflated 33%)
#   adding: content/human-pose-estimation.pytorch/lib/nms/__init__.py (stored 0%)
#   adding: content/human-pose-estimation.pytorch/lib/nms/nms_kernel.cu (deflated 70%)
#   adding: content/human-pose-estimation.pytorch/lib/nms/gpu_nms.pyx (deflated 61%)
#   adding: content/human-pose-estimation.pytorch/lib/nms/setup.py (deflated 61%)
#   adding: content/human-pose-estimation.pytorch/lib/nms/nms.py (deflated 68%)
#   adding: content/human-pose-estimation.pytorch/lib/dataset/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/lib/dataset/__init__.py (deflated 60%)
#   adding: content/human-pose-estimation.pytorch/lib/dataset/mpii.py (deflated 70%)
#   adding: content/human-pose-estimation.pytorch/lib/dataset/coco.py (deflated 72%)
#   adding: content/human-pose-estimation.pytorch/lib/dataset/JointsDataset.py (deflated 70%)
#   adding: content/human-pose-estimation.pytorch/lib/core/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/lib/core/inference.py (deflated 67%)
#   adding: content/human-pose-estimation.pytorch/lib/core/function.py (deflated 73%)
#   adding: content/human-pose-estimation.pytorch/lib/core/loss.py (deflated 66%)
#   adding: content/human-pose-estimation.pytorch/lib/core/evaluate.py (deflated 62%)
#   adding: content/human-pose-estimation.pytorch/lib/core/config.py (deflated 69%)
#   adding: content/human-pose-estimation.pytorch/lib/core/__pycache__/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/lib/core/__pycache__/config.cpython-36.pyc (deflated 43%)
#   adding: content/human-pose-estimation.pytorch/lib/models/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/lib/models/__init__.py (deflated 60%)
#   adding: content/human-pose-estimation.pytorch/lib/models/pose_resnet.py (deflated 79%)
#   adding: content/human-pose-estimation.pytorch/lib/models/__pycache__/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/lib/models/__pycache__/pose_resnet.cpython-36.pyc (deflated 55%)
#   adding: content/human-pose-estimation.pytorch/lib/models/__pycache__/__init__.cpython-36.pyc (deflated 24%)
#   adding: content/human-pose-estimation.pytorch/lib/utils/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/lib/utils/zipreader.py (deflated 70%)
#   adding: content/human-pose-estimation.pytorch/lib/utils/__init__.py (stored 0%)
#   adding: content/human-pose-estimation.pytorch/lib/utils/utils.py (deflated 64%)
#   adding: content/human-pose-estimation.pytorch/lib/utils/vis.py (deflated 73%)
#   adding: content/human-pose-estimation.pytorch/lib/utils/transforms.py (deflated 69%)
#   adding: content/human-pose-estimation.pytorch/experiments/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/resnet152/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/resnet152/256x192_d256x3_adam_lr1e-3_caffe.yaml (deflated 51%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/resnet152/256x192_d256x3_adam_lr1e-3.yaml (deflated 51%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/resnet152/384x288_d256x3_adam_lr1e-3.yaml (deflated 53%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/resnet50/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/resnet50/256x192_d256x3_adam_lr1e-3_caffe.yaml (deflated 51%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/resnet50/256x192_d256x3_adam_lr1e-3.yaml (deflated 51%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/resnet50/384x288_d256x3_adam_lr1e-3.yaml (deflated 53%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/resnet101/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/resnet101/256x192_d256x3_adam_lr1e-3_caffe.yaml (deflated 51%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/resnet101/256x192_d256x3_adam_lr1e-3.yaml (deflated 51%)
#   adding: content/human-pose-estimation.pytorch/experiments/coco/resnet101/384x288_d256x3_adam_lr1e-3.yaml (deflated 53%)
#   adding: content/human-pose-estimation.pytorch/experiments/mpii/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/experiments/mpii/resnet152/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/experiments/mpii/resnet152/384x384_d256x3_adam_lr1e-3.yaml (deflated 50%)
#   adding: content/human-pose-estimation.pytorch/experiments/mpii/resnet152/256x256_d256x3_adam_lr1e-3.yaml (deflated 50%)
#   adding: content/human-pose-estimation.pytorch/experiments/mpii/resnet50/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/experiments/mpii/resnet50/384x384_d256x3_adam_lr1e-3.yaml (deflated 50%)
#   adding: content/human-pose-estimation.pytorch/experiments/mpii/resnet50/256x256_d256x3_adam_lr1e-3.yaml (deflated 50%)
#   adding: content/human-pose-estimation.pytorch/experiments/mpii/resnet101/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/experiments/mpii/resnet101/384x384_d256x3_adam_lr1e-3.yaml (deflated 50%)
#   adding: content/human-pose-estimation.pytorch/experiments/mpii/resnet101/256x256_d256x3_adam_lr1e-3.yaml (deflated 50%)
#   adding: content/human-pose-estimation.pytorch/README.md (deflated 66%)
#   adding: content/human-pose-estimation.pytorch/pose_estimation/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/pose_estimation/train.py (deflated 68%)
#   adding: content/human-pose-estimation.pytorch/pose_estimation/_init_paths.py (deflated 56%)
#   adding: content/human-pose-estimation.pytorch/pose_estimation/valid.py (deflated 68%)
#   adding: content/human-pose-estimation.pytorch/.gitignore (deflated 45%)
#   adding: content/human-pose-estimation.pytorch/.git/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/config (deflated 34%)
#   adding: content/human-pose-estimation.pytorch/.git/refs/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/refs/heads/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/refs/heads/master (deflated 2%)
#   adding: content/human-pose-estimation.pytorch/.git/refs/tags/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/refs/remotes/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/info/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/info/exclude (deflated 28%)
#   adding: content/human-pose-estimation.pytorch/.git/index (deflated 55%)
#   adding: content/human-pose-estimation.pytorch/.git/HEAD (deflated 2%)
#   adding: content/human-pose-estimation.pytorch/.git/hooks/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/human-pose-estimation.pytorch/.git/hooks/pre-commit.sample (deflated 43%)
#   adding: content/human-pose-estimation.pytorch/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/human-pose-estimation.pytorch/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/human-pose-estimation.pytorch/.git/hooks/fsmonitor-watchman.sample (deflated 53%)
#   adding: content/human-pose-estimation.pytorch/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/human-pose-estimation.pytorch/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/human-pose-estimation.pytorch/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/human-pose-estimation.pytorch/.git/hooks/update.sample (deflated 68%)
#   adding: content/human-pose-estimation.pytorch/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/human-pose-estimation.pytorch/.git/hooks/pre-push.sample (deflated 50%)
#   adding: content/human-pose-estimation.pytorch/.git/packed-refs (deflated 11%)
#   adding: content/human-pose-estimation.pytorch/.git/description (deflated 14%)
#   adding: content/human-pose-estimation.pytorch/.git/logs/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/logs/refs/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/logs/refs/heads/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/logs/refs/heads/master (deflated 29%)
#   adding: content/human-pose-estimation.pytorch/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/logs/refs/remotes/origin/HEAD (deflated 29%)
#   adding: content/human-pose-estimation.pytorch/.git/logs/HEAD (deflated 57%)
#   adding: content/human-pose-estimation.pytorch/.git/branches/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/objects/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/objects/info/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/objects/pack/ (stored 0%)
#   adding: content/human-pose-estimation.pytorch/.git/objects/pack/pack-a0d88918d785f41c825a9d6ba542a6fc8a8fb2ca.pack (deflated 2%)
#   adding: content/human-pose-estimation.pytorch/.git/objects/pack/pack-a0d88918d785f41c825a9d6ba542a6fc8a8fb2ca.idx (deflated 13%)
#   adding: content/human-pose-estimation.pytorch/LICENSE (deflated 44%)
#   adding: content/human-pose-estimation.pytorch/CONTRIBUTING.md (deflated 48%)
#   adding: content/pose.jpg (deflated 3%)
#   adding: content/pose_resnet_50_256x256.pth.tar (deflated 7%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/README.md (deflated 42%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/simple_pose_estimation.onnx (deflated 7%)
#   adding: content/simple_pose_estimation.quantized.onnx (deflated 14%)

# %%
# !cp /content/simple_pose_estimation.quantized.onnx /content/gdrive/
